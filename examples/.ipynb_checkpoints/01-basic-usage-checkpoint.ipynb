# %%
import newt
import pandas as pd
# Out:
# load C:\Users\sykcfc\.conda\envs\py38\lib\site-packages\ortools\.libs\zlib1.dll...
# load C:\Users\sykcfc\.conda\envs\py38\lib\site-packages\ortools\.libs\abseil_dll.dll...
# load C:\Users\sykcfc\.conda\envs\py38\lib\site-packages\ortools\.libs\utf8_validity.dll...
# load C:\Users\sykcfc\.conda\envs\py38\lib\site-packages\ortools\.libs\re2.dll...
# load C:\Users\sykcfc\.conda\envs\py38\lib\site-packages\ortools\.libs\libprotobuf.dll...
# load C:\Users\sykcfc\.conda\envs\py38\lib\site-packages\ortools\.libs\highs.dll...
# load C:\Users\sykcfc\.conda\envs\py38\lib\site-packages\ortools\.libs\ortools.dll...
# (CVXPY) Jan 07 06:51:02 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.12.4544). Expected < 9.8.0. Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) Jan 07 06:51:02 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.12.4544). Expected < 9.8.0. Please open a feature request on cvxpy to enable support for this version.')

# %%
def load_german_data(path):
    columns = [
        "status",
        "duration",
        "credit_history",
        "purpose",
        "credit_amount",
        "savings",
        "employment",
        "installment_rate",
        "personal_status_sex",
        "guarantors",
        "residence_since",
        "property",
        "age",
        "other_installment",
        "housing",
        "existing_credits",
        "job",
        "maintenance_people",
        "telephone",
        "foreign_worker",
        "target",
    ]
    df = pd.read_csv(path, sep=" ", header=None, names=columns)
    # Target: 1=Good, 2=Bad. Map to 0=Good, 1=Bad (default risk modeling)
    df["target"] = df["target"].map({1: 0, 2: 1})
    return df

# %%
df = load_german_data('./data/statlog+german+credit+data/german.data')

# %%
fs = newt.FeatureSelector()

# %%
fs.fit(df,df['target'])

# %%
fs.report()
# Out:
#                 feature        dtype  count  correlation         iv        ks  \
# 0                status  categorical   1000          NaN   0.666012       NaN
# 1              duration      numeric   1000     0.214927   0.246542  0.191905
# 2        credit_history  categorical   1000          NaN   0.293234       NaN
# 3               purpose  categorical   1000          NaN   0.169195       NaN
# 4         credit_amount      numeric   1000     0.154739   0.113637  0.157143
# 5               savings  categorical   1000          NaN   0.196010       NaN
# 6            employment  categorical   1000          NaN   0.086434       NaN
# 7      installment_rate      numeric   1000     0.072404   0.026322  0.077143
# 8   personal_status_sex  categorical   1000          NaN   0.044671       NaN
# 9            guarantors  categorical   1000          NaN   0.032019       NaN
# 10      residence_since      numeric   1000     0.002967   0.003589  0.014286
# 11             property  categorical   1000          NaN   0.112638       NaN
# 12                  age      numeric   1000    -0.091127   0.100622  0.131429
# 13    other_installment  categorical   1000          NaN   0.057615       NaN
# 14              housing  categorical   1000          NaN   0.083293       NaN
# 15     existing_credits      numeric   1000    -0.045732   0.013267  0.048095
# 16                  job  categorical   1000          NaN   0.008763       NaN
# 17   maintenance_people      numeric   1000    -0.003015   0.000043  0.002381
# 18            telephone  categorical   1000          NaN   0.006378       NaN
# 19       foreign_worker  categorical   1000          NaN   0.043877       NaN
# 20               target      numeric   1000     1.000000  36.841361  1.000000
#
#     kurtosis      max      mean  median    min  missing_rate  skewness  \
# 0        NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 1   0.909195     72.0    20.903    18.0    4.0           0.0  1.092542
# 2        NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 3        NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 4   4.265163  18424.0  3271.258  2319.5  250.0           0.0  1.946702
# 5        NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 6        NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 7  -1.210423      4.0     2.973     3.0    1.0           0.0 -0.530551
# 8        NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 9        NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 10 -1.380545      4.0     2.845     3.0    1.0           0.0 -0.272161
# 11       NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 12  0.586811     75.0    35.546    33.0   19.0           0.0  1.019208
# 13       NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 14       NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 15  1.590434      4.0     1.407     1.0    1.0           0.0  1.270666
# 16       NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 17  1.635045      2.0     1.155     1.0    1.0           0.0  1.906579
# 18       NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 19       NaN      NaN       NaN     NaN    NaN           0.0       NaN
# 20 -1.238095      1.0     0.300     0.0    0.0           0.0  0.872872
#
#             std    status reason
# 0           NaN  selected
# 1     12.058814  selected
# 2           NaN  selected
# 3           NaN  selected
# 4   2822.736876  selected
# 5           NaN  selected
# 6           NaN  selected
# 7      1.118715  selected
# 8           NaN  selected
# 9           NaN  selected
# 10     1.103718  selected
# 11          NaN  selected
# 12    11.375469  selected
# 13          NaN  selected
# 14          NaN  selected
# 15     0.577654  selected
# 16          NaN  selected
# 17     0.362086  selected
# 18          NaN  selected
# 19          NaN  selected
# 20     0.458487  selected

# %%
categorical_list = fs.report().loc[fs.report()['dtype']=='categorical', 'feature'].tolist()

# %%
from sklearn.preprocessing import LabelEncoder
from typing import List, Dict

def label_encode_multiple_columns(df: pd.DataFrame, columns: List[str]):
    """
    对DataFrame中的多个分类列进行标签编码
    
    Args:
        df: 输入的DataFrame
        columns: 需要编码的列名列表
    
    Returns:
        (编码后的DataFrame, 编码器字典)
    """
    df_encoded = df.copy()
    encoders = {}
    
    for col in columns:
        if col in df_encoded.columns:
            encoder = LabelEncoder()
            # 处理缺失值：先将NaN替换为字符串'NaN'，避免编码错误
            series_clean = df_encoded[col].fillna('NaN').astype(str)
            df_encoded[col] = encoder.fit_transform(series_clean)
            encoders[col] = encoder
    
    return df_encoded, encoders

# %%
df_encoded, encoders = label_encode_multiple_columns(df, categorical_list)

# %%
fs.fit(df_encoded,df['target'])

# %%
fs.report().sort_values(by='iv', ascending=False)
# Out:
#                 feature    dtype  count  correlation         iv        ks  \
# 20               target  numeric   1000     1.000000  36.841361  1.000000
# 0                status  numeric   1000    -0.350847   0.666012  0.367143
# 2        credit_history  numeric   1000    -0.228785   0.293234  0.180476
# 1              duration  numeric   1000     0.214927   0.246542  0.191905
# 5               savings  numeric   1000    -0.178943   0.196010  0.186667
# 3               purpose  numeric   1000     0.001514   0.169195  0.089524
# 4         credit_amount  numeric   1000     0.154739   0.113637  0.157143
# 11             property  numeric   1000     0.142612   0.112638  0.117143
# 12                  age  numeric   1000    -0.091127   0.100622  0.131429
# 6            employment  numeric   1000    -0.116002   0.086434  0.119524
# 14              housing  numeric   1000    -0.019315   0.083293  0.077619
# 13    other_installment  numeric   1000    -0.109844   0.057615  0.096190
# 8   personal_status_sex  numeric   1000    -0.088184   0.044671  0.100000
# 19       foreign_worker  numeric   1000    -0.082079   0.043877  0.033810
# 9            guarantors  numeric   1000    -0.025137   0.032019  0.026667
# 7      installment_rate  numeric   1000     0.072404   0.026322  0.077143
# 15     existing_credits  numeric   1000    -0.045732   0.013267  0.048095
# 16                  job  numeric   1000     0.032735   0.008763  0.031429
# 18            telephone  numeric   1000    -0.036466   0.006378  0.039048
# 10      residence_since  numeric   1000     0.002967   0.003589  0.014286
# 17   maintenance_people  numeric   1000    -0.003015   0.000043  0.002381
#
#      kurtosis      max      mean  median    min  missing_rate  skewness  \
# 20  -1.238095      1.0     0.300     0.0    0.0           0.0  0.872872
# 0   -1.661390      3.0     1.577     1.0    0.0           0.0  0.006947
# 2   -0.582158      4.0     2.545     2.0    0.0           0.0 -0.011868
# 1    0.909195     72.0    20.903    18.0    4.0           0.0  1.092542
# 5   -0.682822      4.0     1.105     0.0    0.0           0.0  1.015151
# 3   -0.342804      9.0     3.277     3.0    0.0           0.0  0.625715
# 4    4.265163  18424.0  3271.258  2319.5  250.0           0.0  1.946702
# 11  -1.238325      3.0     1.358     1.0    0.0           0.0  0.045605
# 12   0.586811     75.0    35.546    33.0   19.0           0.0  1.019208
# 6   -0.935659      4.0     2.384     2.0    0.0           0.0 -0.117438
# 14   0.464620      2.0     0.929     1.0    0.0           0.0 -0.070698
# 13   1.499041      2.0     1.675     2.0    0.0           0.0 -1.823777
# 8   -0.008548      3.0     1.682     2.0    0.0           0.0 -0.304688
# 19  22.065449      1.0     0.037     0.0    0.0           0.0  4.905655
# 9    9.276184      2.0     0.145     0.0    0.0           0.0  3.259350
# 7   -1.210423      4.0     2.973     3.0    1.0           0.0 -0.530551
# 15   1.590434      4.0     1.407     1.0    1.0           0.0  1.270666
# 16   0.493391      3.0     1.904     2.0    0.0           0.0 -0.373733
# 18  -1.846900      1.0     0.404     0.0    0.0           0.0  0.391280
# 10  -1.380545      4.0     2.845     3.0    1.0           0.0 -0.272161
# 17   1.635045      2.0     1.155     1.0    1.0           0.0  1.906579
#
#             std    status reason
# 20     0.458487  selected
# 0      1.257638  selected
# 2      1.083120  selected
# 1     12.058814  selected
# 5      1.580023  selected
# 3      2.739302  selected
# 4   2822.736876  selected
# 11     1.050209  selected
# 12    11.375469  selected
# 6      1.208306  selected
# 14     0.531264  selected
# 13     0.705601  selected
# 8      0.708080  selected
# 19     0.188856  selected
# 9      0.477706  selected
# 7      1.118715  selected
# 15     0.577654  selected
# 16     0.653614  selected
# 18     0.490943  selected
# 10     1.103718  selected
# 17     0.362086  selected

# %%
newt.PreFilter()
